# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
import pickle

# device=torch.device("cpu")

# %% [markdown]
# ## Base

# %%
# %%capture val
# !python run_reconstruct_mae.py --data_path /Users/albertwen/Downloads/mae_data/ImageNet-Data/val --mask_ratio 0.75 --batch_size 1 --resume /Users/albertwen/Downloads/mae_data/checkpoint-109.pth --mlp_resume /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth --output_dir output/reconstruct_mae_pretrain_model/ --device cpu --eval

# python run_reconstruct_mae.py
# --data_path /Users/albertwen/Downloads/mae_data/ImageNet-Data/val
# --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1
# --resume /Users/albertwen/Downloads/mae_data/checkpoint-109.pth
# --mlp_resume /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth
# --output_dir output/reconstruct_mae_pretrain_model/
# --device cpu
# --eval

# local path: 
# /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth

# %%
# with open("/Users/albertwen/Downloads/mae_data/val_losses.pkl", "wb") as f:
#     pickle.dump(val.stdout, f)

# %%
split_val = val.stdout.split('\n')
pattern = re.compile("Epoch: .*")
val_cleaned_losses = [i for i in split_val if pattern.match(i)][:-1]
val_cleaned_losses = [float(re.search('loss: (0\.\d*) .*', i).group(1)) for i in val_cleaned_losses]

# %%
plt.plot(val_cleaned_losses)

# %% [markdown]
# ## FGSM4

# %%
# %%capture fgsm4
# !python run_reconstruct_mae.py --data_path /Users/albertwen/Downloads/mae_data/ImageNet-Data/attack/val/fgsm_4 --mask_ratio 0.75 --batch_size 1 --resume /Users/albertwen/Downloads/mae_data/checkpoint-109.pth --mlp_resume /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth --output_dir output/reconstruct_mae_pretrain_model/ --device cpu --eval

# python run_reconstruct_mae.py
# --data_path /Users/albertwen/Downloads/mae_data/ImageNet-Data/val
# --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1
# --resume /Users/albertwen/Downloads/mae_data/checkpoint-109.pth
# --mlp_resume /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth
# --output_dir output/reconstruct_mae_pretrain_model/
# --device cpu
# --eval

# local path: 
# /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth

# %%
split = fgsm4.stdout.split('\n')
pattern = re.compile("Epoch: .*")
cleaned_losses = [i for i in split if pattern.match(i)][:-1]
cleaned_losses = [float(re.search('loss: (0\.\d*) .*', i).group(1)) for i in cleaned_losses]

# %%
plt.plot(cleaned_losses)

# %%
# with open("/Users/albertwen/Downloads/mae_data/fgsm4_losses.pkl", "wb") as f:
#     pickle.dump(fgsm4.stdout, f)

# %% [markdown]
# ## FGSM8

# %%
# %%capture fgsm8
# !python run_reconstruct_mae.py --data_path /Users/albertwen/Downloads/mae_data/ImageNet-Data/attack/val/fgsm_8 --mask_ratio 0.75 --batch_size 1 --resume /Users/albertwen/Downloads/mae_data/checkpoint-109.pth --mlp_resume /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth --output_dir output/reconstruct_mae_pretrain_model/ --device cpu --eval

# python run_reconstruct_mae.py
# --data_path /Users/albertwen/Downloads/mae_data/ImageNet-Data/val
# --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1
# --resume /Users/albertwen/Downloads/mae_data/checkpoint-109.pth
# --mlp_resume /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth
# --output_dir output/reconstruct_mae_pretrain_model/
# --device cpu
# --eval

# local path: 
# /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth

# %%
split = fgsm8.stdout.split('\n')
pattern = re.compile("Epoch: .*")
cleaned_losses = [i for i in split if pattern.match(i)][:-1]
cleaned_losses = [float(re.search('loss: (0\.\d*) .*', i).group(1)) for i in cleaned_losses]

# %%
plt.plot(cleaned_losses)

# %%
# with open("/Users/albertwen/Downloads/mae_data/fgsm8_losses.pkl", "wb") as f:
#     pickle.dump(fgsm8.stdout, f)

# %% [markdown]
# ## PGDL2

# %%
# %%capture pgdl2
# !python run_reconstruct_mae.py --data_path /Users/albertwen/Downloads/mae_data/ImageNet-Data/attack/val/pgd_l2 --mask_ratio 0.75 --batch_size 1 --resume /Users/albertwen/Downloads/mae_data/checkpoint-109.pth --mlp_resume /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth --output_dir output/reconstruct_mae_pretrain_model/ --device cpu --eval

# python run_reconstruct_mae.py
# --data_path /Users/albertwen/Downloads/mae_data/ImageNet-Data/val
# --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1
# --resume /Users/albertwen/Downloads/mae_data/checkpoint-109.pth
# --mlp_resume /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth
# --output_dir output/reconstruct_mae_pretrain_model/
# --device cpu
# --eval

# local path: 
# /Users/albertwen/Downloads/mae_data/mlp-checkpoint-109.pth

# with open("/Users/albertwen/Downloads/mae_data/pgdl2_losses.pkl", "wb") as f:
#     pickle.dump(pgdl2.stdout, f)

# %%
split = pgdl2.stdout.split('\n')
pattern = re.compile("Epoch: .*")
cleaned_losses = [i for i in split if pattern.match(i)][:-1]
cleaned_losses = [float(re.search('loss: (0\.\d*) .*', i).group(1)) for i in cleaned_losses]

# %%
plt.plot(cleaned_losses)
