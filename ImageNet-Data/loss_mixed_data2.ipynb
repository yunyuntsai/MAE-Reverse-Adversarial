# %% [markdown]
# # Top

# %%
import pickle
import pandas as pd
import numpy as np
from scipy.stats import ks_2samp
import re
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
def ks_plot_comp(data_1, data_2):
    plt.figure(figsize=(12, 7))
    plt.scatter(data_1, range(len(data_1)), label="base loss", alpha=0.3, s=2)
    plt.scatter(data_2, range(len(data_2)), label="attack loss", alpha=0.3, s=2)
    plt.legend('top right')
    plt.title('Comparing 2 data distributions for KS-Test')
    plt.show()

# %%
with open("output/base_loss.pkl", "rb") as f:
    base_loss_values = pickle.load(f)

# %% [markdown]
# ### PGDl2 + base

# %%
# %%capture losses
# !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\pgd_l2" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\pgd_l2" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

# %%
pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
mixed_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

# %%
with open("output/pgdl2_mixed2.pkl", "wb") as f:
    pickle.dump(mixed_losses, f)

# %%
ks_plot_comp(base_loss_values, mixed_losses)

# %% [markdown]
# ### PGD8 + Base

# %%
# %%capture losses
# !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\pgd_8" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\pgd_8" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

# %%
pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
mixed_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

# %%
ks_plot_comp(base_loss_values, mixed_losses)

# %%
with open("output/pgd8_mixed2.pkl", "wb") as f:
    pickle.dump(mixed_losses, f)

# %% [markdown]
# ### PGD16 + Base

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\pgd_16" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
mixed_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

with open("output/pgd16_mixed2.pkl", "wb") as f:
    pickle.dump(mixed_losses, f)

# %%
ks_plot_comp(base_loss_values, mixed_losses)

# %% [markdown]
# ### FGSM4 + Base

# %%
# %%capture losses
# !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\fgsm_4" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\fgsm_4" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

# %%
pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
mixed_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

# %%
ks_plot_comp(base_loss_values, mixed_losses)

# %%
with open("output/fgsm4_mixed2.pkl", "wb") as f:
    pickle.dump(mixed_losses, f)

# %% [markdown]
# ### FGSM8 + Base

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\fgsm_8" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
mixed_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

with open("output/fgsm8_mixed2.pkl", "wb") as f:
    pickle.dump(mixed_losses, f)

# %%
ks_plot_comp(base_loss_values, mixed_losses)

# %% [markdown]
# ### FGSM16 + Base

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "c:\Users\Albert Wen\ml_security\Attack\fgsm_16" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
mixed_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

with open("output/fgsm16_mixed2.pkl", "wb") as f:
    pickle.dump(mixed_losses, f)

# %%
ks_plot_comp(base_loss_values, mixed_losses)

# %% [markdown]
# ### apgd + Base

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\apgd" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

# %%
# output_lines = losses.stdout.split('\n')

pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
apgd_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

# %%
ks_plot_comp(base_loss_values, apgd_losses)

# %%
with open("output/apgd_mixed2.pkl", "wb") as f:
    pickle.dump(apgd_losses, f)

# %% [markdown]
# ### CW_L2 + Base

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\cw_l2" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
mixed_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

with open("output/cwl2_mixed2.pkl", "wb") as f:
    pickle.dump(mixed_losses, f)

# %%
ks_plot_comp(base_loss_values, mixed_losses)

# %% [markdown]
# ### BIM_8 + Base

# %%
losses = !python ../run_reconstruct_mae.py --two_data_paths True --data_path1 "c:\Users\Albert Wen\ml_security\ImageNet-Data\val" --data_path2 "\\wsl$\Ubuntu\home\awen\bim_8" --mask_ratio 0.75 --model pretrain_mae_base_patch16_224 --batch_size 1 --resume ../output/reconstruct_mae_pretrain_model/checkpoint-109.pth --mlp_resume ../output/reconstruct_mae_pretrain_model/mlp-checkpoint-109.pth --output_dir ../output/reconstruct_mae_pretrain_model/ --eval --num_workers 1

pattern = re.compile('loss: (\d.\d*) ')

epoch_lines = [x for x in losses if x[0:5] == 'Epoch']
mixed_losses = [float(pattern.findall(x)[0]) for x in epoch_lines[:-1] if pattern.findall(x) != []]

with open("output/bim8_mixed2.pkl", "wb") as f:
    pickle.dump(mixed_losses, f)

# %%
ks_plot_comp(base_loss_values, mixed_losses)
